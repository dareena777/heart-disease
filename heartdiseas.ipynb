# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import math
# %matplotlib inline

import os

# %%
data = pd.read_csv("C:/Users/Dareen/OneDrive/Desktop/heartdiseas/heart.csv")
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope
# 0   63    1   3       145   233    1        0      150      0      2.3      0  \
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000  \
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000  \
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
x=data.drop('target',axis=1)
y=data['target']

# %%
y.describe()
# Out:
# count    303.000000
# mean       0.544554
# std        0.498835
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: target, dtype: float64

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 303 entries, 0 to 302
# Series name: target
# Non-Null Count  Dtype
# --------------  -----
# 303 non-null    int64
# dtypes: int64(1)
# memory usage: 2.5 KB

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
# dtypes: float64(1), int64(12)
# memory usage: 30.9 KB

# %%
print(data.corr()["target"].abs().sort_values(ascending=False))
# Out:
# target      1.000000
# exang       0.436757
# cp          0.433798
# oldpeak     0.430696
# thalach     0.421741
# ca          0.391724
# slope       0.345877
# thal        0.344029
# sex         0.280937
# age         0.225439
# trestbps    0.144931
# restecg     0.137230
# chol        0.085239
# fbs         0.028046
# Name: target, dtype: float64

# %%
female_data=data[data["sex"] == 1]
sb.countplot(data=female_data,x='target')
plt.xlabel("femals with the heart diseas")
# Out:
# Text(0.5, 0, 'femals with the heart diseas')

# %%
male_data=data[data["sex"] == 0]
sb.countplot(data=male_data,x='target')
plt.xlabel("malels with the heart diseas")
# Out:
# Text(0.5, 0, 'malels with the heart diseas')

# %%
age_data=data[data["age"] >= 55]
sb.countplot(data=age_data,x='target')
plt.xlabel(" old people with the heart diseas")
# Out:
# Text(0.5, 0, ' old people with the heart diseas')

# %%
age_data2=data[data["age"] <= 50]
sb.countplot(data=age_data2,x='target')
plt.xlabel(" young people with the heart diseas")
# Out:
# Text(0.5, 0, ' young people with the heart diseas')

# %%
cp0=data[data["cp"] == 0]
sb.countplot(data=cp0,x='target')
plt.xlabel(" people with the heart diseas")
# Out:
# Text(0.5, 0, ' people with the heart diseas')

# %%
cp1=data[data["cp"] == 1]
sb.countplot(data=cp1,x='target')
plt.xlabel(" people with the heart diseas")
# Out:
# Text(0.5, 0, ' people with the heart diseas')

# %%
cp2=data[data["cp"] == 2]
sb.countplot(data=cp2,x='target')
plt.xlabel(" people with the heart diseas")
# Out:
# Text(0.5, 0, ' people with the heart diseas')

# %%
cp3=data[data["cp"] == 3]
sb.countplot(data=cp3,x='target')
plt.xlabel("  people with the heart diseas")
# Out:
# Text(0.5, 0, '  people with the heart diseas')

# %%
print(data['exang'].unique())
# Out:
# [0 1]

# %%
exang0=data[data["exang"] == 0]
sb.countplot(data=exang0,x='target')
plt.xlabel(" people with the heart diseas")
# Out:
# Text(0.5, 0, ' people with the heart diseas')

# %%
exang1=data[data["exang"] == 1]
sb.countplot(data=exang1,x='target')
plt.xlabel(" people with the heart diseas")
# Out:
# Text(0.5, 0, ' people with the heart diseas')

# %%
print(data['oldpeak'].unique())
# Out:
# [2.3 3.5 1.4 0.8 0.6 0.4 1.3 0.  0.5 1.6 1.2 0.2 1.8 1.  2.6 1.5 3.  2.4
#  0.1 1.9 4.2 1.1 2.  0.7 0.3 0.9 3.6 3.1 3.2 2.5 2.2 2.8 3.4 6.2 4.  5.6
#  2.9 2.1 3.8 4.4]

# %%
oldpeak1=data[data["oldpeak"] >= 2]
sb.countplot(data=oldpeak1,x='target')
plt.xlabel(" people with the heart diseas")
# Out:
# Text(0.5, 0, ' people with the heart diseas')

# %%
oldpeak2=data[data["oldpeak"] <= 2]
sb.countplot(data=oldpeak2,x='target')
plt.xlabel(" people with the heart diseas")
# Out:
# Text(0.5, 0, ' people with the heart diseas')

# %%
thalach1=data[data["thalach"] >= 150]
sb.countplot(data=thalach1,x='target')
plt.xlabel(" people with the heart diseas")
# Out:
# Text(0.5, 0, ' people with the heart diseas')

# %%
thalach2=data[data["thalach"] <= 120]
sb.countplot(data=thalach2,x='target')
plt.xlabel(" people with the heart diseas")
# Out:
# Text(0.5, 0, ' people with the heart diseas')

# %%
print(data['ca'].unique())
# Out:
# [0 2 1 3 4]

# %%
ca4=data[data["ca"] == 4]
sb.countplot(data=ca4,x='target')
plt.xlabel(" people with the heart diseas")
# Out:
# Text(0.5, 0, ' people with the heart diseas')

# %%
ca3=data[data["ca"] == 3]
sb.countplot(data=ca3,x='target')
plt.xlabel(" people with the heart diseas")
# Out:
# Text(0.5, 0, ' people with the heart diseas')

# %%
ca2=data[data["ca"] == 2]
sb.countplot(data=ca2,x='target')
plt.xlabel(" people with the heart diseas")
# Out:
# Text(0.5, 0, ' people with the heart diseas')

# %%
ca1=data[data["ca"] == 1]
sb.countplot(data=ca1,x='target')
plt.xlabel(" people with the heart diseas")
# Out:
# Text(0.5, 0, ' people with the heart diseas')

# %%
ca0=data[data["ca"] == 0]
sb.countplot(data=ca0,x='target')
plt.xlabel(" people with the heart diseas")
# Out:
# Text(0.5, 0, ' people with the heart diseas')

# %%
print(data['slope'].unique())
# Out:
# [0 2 1]

# %%
slope0=data[data["slope"] == 0]
sb.countplot(data=slope0,x='target')
plt.xlabel(" people with the heart diseas")
# Out:
# Text(0.5, 0, ' people with the heart diseas')

# %%
slope1=data[data["slope"] == 1]
sb.countplot(data=slope1,x='target')
plt.xlabel(" people with the heart diseas")
# Out:
# Text(0.5, 0, ' people with the heart diseas')

# %%
slope2=data[data["slope"] == 2]
sb.countplot(data=slope2,x='target')
plt.xlabel(" people with the heart diseas")
# Out:
# Text(0.5, 0, ' people with the heart diseas')

# %%
print(data['thal'].unique())
# Out:
# [1 2 3 0]

# %%
thal3=data[data["thal"] == 3]
sb.countplot(data=thal3,x='target')
plt.xlabel(" people with the heart diseas")
# Out:
# Text(0.5, 0, ' people with the heart diseas')

# %%
thal2=data[data["thal"] == 2]
sb.countplot(data=thal2,x='target')
plt.xlabel(" people with the heart diseas")
# Out:
# Text(0.5, 0, ' people with the heart diseas')

# %%
thal1=data[data["thal"] == 1]
sb.countplot(data=thal1,x='target')
plt.xlabel(" people with the heart diseas")
# Out:
# Text(0.5, 0, ' people with the heart diseas')

# %%
thal0=data[data["thal"] == 0]
sb.countplot(data=thal0,x='target')
plt.xlabel(" people with the heart diseas")
# Out:
# Text(0.5, 0, ' people with the heart diseas')

# %%
print("Percentage of patience with heart problems: "+str(y.where(y==1).count()*100/303))
print("Percentage of patience with no heart problems: "+str(y.where(y==0).count()*100/303))
# Out:
# Percentage of patience with heart problems: 54.45544554455446
# Percentage of patience with no heart problems: 45.54455445544554

# %%
sb.barplot(x=data["cp"],y=y)
# Out:
# <Axes: xlabel='cp', ylabel='target'>

# %%
data["restecg"].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
sb.barplot(x=data["restecg"],y=y)
# Out:
# <Axes: xlabel='restecg', ylabel='target'>

# %%
sb.distplot(data["thal"])
# Out:
# C:\Users\Dareen\AppData\Local\Temp\ipykernel_64972\2758710923.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(data["thal"])
# <Axes: xlabel='thal', ylabel='Density'>

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.20,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(X_train,Y_train)

Y_pred_lr = lr.predict(X_test)
# Out:
# c:\Users\Dareen\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
score_lr = round(accuracy_score(Y_pred_lr,Y_test)*100,2)

print("The accuracy score achieved using Logistic Regression is: "+str(score_lr)+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 85.25 %

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

nb.fit(X_train,Y_train)

Y_pred_nb = nb.predict(X_test)

# %%
score_nb = round(accuracy_score(Y_pred_nb,Y_test)*100,2)

print("The accuracy score achieved using Naive Bayes is: "+str(score_nb)+" %")
# Out:
# The accuracy score achieved using Naive Bayes is: 85.25 %

# %%
from sklearn import svm

sv = svm.SVC(kernel='linear')

sv.fit(X_train, Y_train)

Y_pred_svm = sv.predict(X_test)

# %%
score_svm = round(accuracy_score(Y_pred_svm,Y_test)*100,2)

print("The accuracy score achieved using Linear SVM is: "+str(score_svm)+" %")
# Out:
# The accuracy score achieved using Linear SVM is: 81.97 %

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train,Y_train)
Y_pred_knn=knn.predict(X_test)

# %%
score_knn = round(accuracy_score(Y_pred_knn,Y_test)*100,2)

print("The accuracy score achieved using KNN is: "+str(score_knn)+" %")
# Out:
# The accuracy score achieved using KNN is: 67.21 %

# %%
from sklearn.tree import DecisionTreeClassifier

max_accuracy = 0


for x in range(200):
    dt = DecisionTreeClassifier(random_state=x)
    dt.fit(X_train,Y_train)
    Y_pred_dt = dt.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_dt,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x
        


dt = DecisionTreeClassifier(random_state=best_x)
dt.fit(X_train,Y_train)
Y_pred_dt = dt.predict(X_test)

# %%
score_dt = round(accuracy_score(Y_pred_dt,Y_test)*100,2)

print("The accuracy score achieved using Decision Tree is: "+str(score_dt)+" %")
# Out:
# The accuracy score achieved using Decision Tree is: 81.97 %

# %%
import xgboost as xgb

xgb_model = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
xgb_model.fit(X_train, Y_train)

Y_pred_xgb = xgb_model.predict(X_test)

# %%
score_xgb = round(accuracy_score(Y_pred_xgb,Y_test)*100,2)

print("The accuracy score achieved using XGBoost is: "+str(score_xgb)+" %")
# Out:
# The accuracy score achieved using XGBoost is: 83.61 %
